# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## Crowdfunding
#
# El *crowdfunding* es un mecanismo para financiar proyectos que consiste en juntar fondos a través de una gran cantidad de personas. Existen diversas formas en las cuales los participantes (o financistas) son compensados, desde un agradecimiento simbólico hasta la posibilidad de disfrutar de los frutos del proyecto. Plataformas online como Kickstarter, Indiegogo y Patreon, entre otras, han popularizado este fenómeno.
#
# En este caso, trabajaremos con datos provenientes de Kickstarter. Esta plataforma usa un modelo de *all-or-nothing*, en donde el creador del proyecto fija una meta (en dinero) y un plazo para cumplirla. Si esta meta se cumple dentro del plazo, el proyecto se queda con el dinero (pagando una comisión a Kickstarter), de lo contrario los participantes o *backers* reciben su dinero de vuelta.
#
# La pregunta que motiva este caso es: ¿Qué proyectos de crowdfunding son más exitosos?

# %% [markdown]
# ## Base de datos
#
# El archivo `kickstarter.csv` contiene datos de proyectos lanzados en Kickstarter, los cuales fueron recolectados durante el año 2018. Todos estos proyectos tuvieron al menos 50 backers y terminaron en alguno de los siguientes tres estados:
#
# - **Exitoso (successful)**: se llegó la meta antes del plazo.
# - **Fallido (failed)**: se cumplió el plazo y no se llegó a la meta.
# - **Cancelado (canceled)**: por alguna razón la campaña fue cancelada.
#
# La descripción de las variables en la base de datos es la siguiente:
#
# ## `kickstarter.csv`

# %% [markdown]
# ## Objetivo
#
# El objetivo de cada grupo es proponer qué tipo de campaña de crowdfunding sería conveniente lanzar, a partir de los datos.
#
# Para ello, sigan los siguientes pasos:
#
# 1. **Describir la base de datos**. ¿cuántos proyectos hay en la base de datos? ¿qué tipo de variables hay en la base de datos (cuantitativas, cualitativas, ordinales, nominales, de razón, de intervalo)? ¿cómo se distribuyen los datos según las distintas variables? Utilice tablas y/o gráficos.
# 2. **Definir un criterio**, basado en los datos, para determinar qué hace que un proyecto sea bueno. ¿Cómo cambiaría este criterio si Kickstarter no utilizara el modelo *all-or-nothing*?
# 3. **Determine el tipo de proyecto para la campaña de crowdfunding que su grupo recomienda**, usando los criterios definidos anteriormente.

# %%
#CARGAMOS LA BASE DE DATOS
ks = pd.read_csv("https://github.com/rocarvaj/analitica-descriptiva/raw/main/datos/kickstarter/kickstarter.csv")
ks
# Out:
#                ID                                               name  \
# 0      1730140959    Beaconz - The App to Map Everything! (Canceled)
# 1      1689190720          Character Trait Endorsing Between Friends
# 2      1719536806  Project Portal - People helping people, for fr...
# 3       903714362    On the Record - Inside the World of Stenography
# 4       166739996        C Grayson Ponchos, "Our Fashion is the ART"
# ...           ...                                                ...
# 95862   313363232                Contour Electric Blue Playing Cards
# 95863  1863949134  Clash of the Monsters - The Horror Genre Fight...
# 95864  1728934253                   Dropship Custom LEGO Element Kit
# 95865   236314934  Show Dogs: Small business in the Great Lakes r...
# 95866   570806201                                        Open Verses
#
#              category main_category currency       state  backers country  \
# 0                Apps    Technology      GBP    canceled        5      GB
# 1                Apps    Technology      USD      failed        3      US
# 2                 Web    Technology      USD      failed        2      US
# 3         Documentary  Film & Video      USD  successful        9      US
# 4             Fashion       Fashion      USD      failed        8      US
# ...               ...           ...      ...         ...      ...     ...
# 95862   Playing Cards         Games      USD  successful      106      US
# 95863     Video Games         Games      USD  successful       40      US
# 95864  Product Design        Design      USD  successful       67      US
# 95865     Food Trucks          Food      USD      failed        1      US
# 95866         Hip-Hop         Music      USD      failed        1      US
#
#        usd_pledged_real  usd_goal_real
# 0               8127.18       92424.29
# 1                 35.00       10000.00
# 2                 51.00        1500.00
# 3              15151.10       14900.00
# 4                211.00       30000.00
# ...                 ...            ...
# 95862           2975.00        2500.00
# 95863           1722.00        1000.00
# 95864           5747.00        3200.00
# 95865              3.00        9990.00
# 95866              2.00        1500.00
#
# [95867 rows x 10 columns]

# %% [markdown]
# ##1. Describir la base de datos

# %% [markdown]
# ¿Cuántos proyectos hay en la base de datos?

# %%
proyectos= ks['ID'].nunique()
print(f'La cantidad de proyectos en la base de datos es de {proyectos}')
# Out:
# La cantidad de proyectos en la base de datos es de 95867

# %%
proyectos= ks['name'].nunique()
print(f'La cantidad de proyectos en la base de datos es de {proyectos}')
# Out:
# La cantidad de proyectos en la base de datos es de 95646

# %% [markdown]
# ¿Qué tipo de variables hay en la base de datos(cuantitativas, cualitativas, ordinales, nomidales, de razón, de internvalo?

# %% [markdown]
# * **ID**: Variable cualitativa nominal, valores numéricos unicos que representan el identificador para cada proyecto.
# * **name**: Variable cualitativa nominal, nombre del proyecto.
# * **category**: Variable cualitativa nominal, describe la categoría especifica del proyecto o subcategoría.
# * **main_category**: Variable cualitativa nominal, describe la categoria global o principal del proyecto.
# * **currency**: Variable cualitativa nominal, es la Moneda en la que los fondos fueron recolectados
# * **state**: Variable cualitativa nominal, estado de proyecto.
# * **backers**:Variable cuantitativa de razón, es el número de backers o participantes del proyecto.
# * **country**: Variable cualitativa nominal, país del proyecto.
# * **usd_pledged_real**: Variable cuantitativa de razón, Monto total reunido en USD.
# * **usd_goal_real**: Variable cuantitativa de razón, Meta en USD de la campaña.

# %% [markdown]
# ¿Cómo se distribuyen los datos según las distintas variables? Utilice tablas y/o gráficos.

# %% [markdown]
# **Gráfico variable "main_category"**
# > Cantidad de proyectos para las 15 categorias globales
#
# > En la siguiente tabla también se puede ver la cantidad de proyectos que hay en cada subcategoría.

# %%
proyectos_maincategory= pd.pivot_table(ks, 
               index=["main_category"], 
               values="ID", 
               aggfunc="count")
proyectos_maincategory=proyectos_maincategory.reset_index()
proyectos_maincategory
# Out:
#    main_category     ID
# 0            Art   7122
# 1         Comics   3074
# 2         Crafts   2087
# 3          Dance    996
# 4         Design   8294
# 5        Fashion   5517
# 6   Film & Video  15930
# 7           Food   6019
# 8          Games   9695
# 9     Journalism   1056
# 10         Music  12852
# 11   Photography   2619
# 12    Publishing   9703
# 13    Technology   7939
# 14       Theater   2964

# %%
fig_proyectos_maincategory = px.bar(proyectos_maincategory,
            x = 'main_category',
            y = 'ID',
            title= 'Cantidad de proyectos para las 15 categorias globales',
            text_auto = True)
fig_proyectos_maincategory = fig_proyectos_maincategory.update_xaxes(categoryorder = 'total descending')
fig_proyectos_maincategory
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f9aeb54b-f4a1-483e-a4fa-121fca47cc0a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9aeb54b-f4a1-483e-a4fa-121fca47cc0a")) {                    Plotly.newPlot(                        "f9aeb54b-f4a1-483e-a4fa-121fca47cc0a",                        [{"alignmentgroup":"True","hovertemplate":"main_category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Art","Comics","Crafts","Dance","Design","Fashion","Film & Video","Food","Games","Journalism","Music","Photography","Publishing","Technology","Theater"],"xaxis":"x","y":[7122,3074,2087,996,8294,5517,15930,6019,9695,1056,12852,2619,9703,7939,2964],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pa ...

# %% [markdown]
# **Gráfico variable "category"**
# > 1. Cantidad de proyectos para las 170 categorias especificas dentro de las 15 categorias globales
#
# > 2. Mayor cantidad de proyectos de cada categoria especifica para cada categoría global.

# %%
#1 Cantidad de proyectos para las 170 categorias especificas dentro de las 15 categorias globales
proyectos_categoria=pd.pivot_table(ks, 
               index=["main_category","category"], 
               values="ID", 
               aggfunc="count")
proyectos_categoria=proyectos_categoria.reset_index()
proyectos_categoria
# Out:
#     main_category        category    ID
# 0             Art             Art  2099
# 1             Art        Ceramics    71
# 2             Art  Conceptual Art   260
# 3             Art     Digital Art   315
# 4             Art    Illustration   852
# ..            ...             ...   ...
# 165       Theater       Immersive    83
# 166       Theater         Musical   236
# 167       Theater           Plays   370
# 168       Theater          Spaces    61
# 169       Theater         Theater  1929
#
# [170 rows x 3 columns]

# %%
fig_proyectos_categoria = px.bar(proyectos_categoria,
            x = 'category',
            y = 'ID',
            color = 'main_category',
            title='Cantidad de proyectos para las categorias especificas dentro de las categorias globales',
            text_auto = True)
fig_proyectos_categoria
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="84cf8801-9fe2-46b0-9e20-f98139829e14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84cf8801-9fe2-46b0-9e20-f98139829e14")) {                    Plotly.newPlot(                        "84cf8801-9fe2-46b0-9e20-f98139829e14",                        [{"alignmentgroup":"True","hovertemplate":"main_category=Art<br>category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"Art","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Art","offsetgroup":"Art","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Art","Ceramics","Conceptual Art","Digital Art","Illustration","Installations","Mixed Media","Painting","Performance Art","Public Art","Sculpture","Textiles","Video Art"],"xaxis":"x","y":[2099,71,260,315,852,124,679,813,560,816,437,55,41],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"main_category=Comics<br>category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"Comics","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Comics","offsetgroup":"Comics","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Anthologies","Comic Books","Comics","Events","Graphic Novels","Webcomics"],"xaxis":"x","y":[119,768,1447,40,531,169],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"main_category=Crafts<br>category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"Crafts","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Crafts","offsetgroup":"Crafts","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Candles","Crafts","Crochet","DIY","Embroidery","Glass","Knitting","Letterpress","Pottery","Printing","Quilts","Stationery","Taxidermy","Weaving","Woodworking"],"xaxis":"x","y":[90,1130,40,265,22,41,51,8,32,48,8,52,4,29,267],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"main_category=Dance<br>category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"Dance","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Dance","offsetgroup":"Dance","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Dance","Performances","Residencies","Spaces","Workshops"],"xaxis":"x","y":[636,254,13,52,41],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"main_category=Design<br>category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"Design","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Design","offsetgroup":"Design","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Architecture","Civic Design","Design","Graphic Design","Interactive Design","Product Design","Typography"],"xaxis":"x","y":[194,83,1146,537,102,6200,32],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"main_category=Fashion<br>category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"Fashion","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Fashion","offsetgroup":"Fashion","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Accessories","Apparel","Childrenswear","Couture","Fashion","Footwear","Jewelry","Pet Fashion","Ready-to-wear"],"xaxis":"x","y":[783,1630,113,47,2176,249,289,44,186],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"main_category=Film & Video<br>category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"Film & Video","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Film & Video","offsetgroup":"Film & Video","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Action","Animation","Comedy","Documentary","Drama","Experimental","Family","Fantasy","Festivals","Film & Video","Horror","Movie Theaters","Music  ...

# %%
#2 Mayor cantidad de proyectos de cada categoria especifica para cada categoría global.
max_category = proyectos_categoria.groupby('main_category')['ID'].idxmax()

# %%
category_max = proyectos_categoria.loc[max_category, ['main_category', 'category', 'ID']]
category_max
# Out:
#     main_category        category    ID
# 0             Art             Art  2099
# 15         Comics          Comics  1447
# 20         Crafts          Crafts  1130
# 34          Dance           Dance   636
# 44         Design  Product Design  6200
# 50        Fashion         Fashion  2176
# 58   Film & Video     Documentary  4185
# 82           Food            Food  2921
# 94          Games  Tabletop Games  4079
# 97     Journalism      Journalism   434
# 115         Music           Music  3449
# 126   Photography     Photography  1431
# 134    Publishing         Fiction  2197
# 159    Technology      Technology  1757
# 169       Theater         Theater  1929

# %%
fig_proyectos_categoria_max = px.bar(category_max,
            x = 'category',
            y = 'ID',
            color = 'main_category',
            title='Mayor cantidad de proyectos de cada categoria especifica para cada categoría global',
            text_auto = True)
fig_proyectos_categoria_max=fig_proyectos_categoria_max.update_xaxes(categoryorder = 'total descending')
fig_proyectos_categoria_max
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c2cd6da7-eeb6-4be7-9a73-da5dd74930c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2cd6da7-eeb6-4be7-9a73-da5dd74930c9")) {                    Plotly.newPlot(                        "c2cd6da7-eeb6-4be7-9a73-da5dd74930c9",                        [{"alignmentgroup":"True","hovertemplate":"main_category=Art<br>category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"Art","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Art","offsetgroup":"Art","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Art"],"xaxis":"x","y":[2099],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"main_category=Comics<br>category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"Comics","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Comics","offsetgroup":"Comics","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Comics"],"xaxis":"x","y":[1447],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"main_category=Crafts<br>category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"Crafts","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Crafts","offsetgroup":"Crafts","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Crafts"],"xaxis":"x","y":[1130],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"main_category=Dance<br>category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"Dance","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Dance","offsetgroup":"Dance","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Dance"],"xaxis":"x","y":[636],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"main_category=Design<br>category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"Design","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Design","offsetgroup":"Design","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Product Design"],"xaxis":"x","y":[6200],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"main_category=Fashion<br>category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"Fashion","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Fashion","offsetgroup":"Fashion","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Fashion"],"xaxis":"x","y":[2176],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"main_category=Film & Video<br>category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"Film & Video","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Film & Video","offsetgroup":"Film & Video","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Documentary"],"xaxis":"x","y":[4185],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"main_category=Food<br>category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"Food","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Food","offsetgroup":"Food","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Food"],"xaxis":"x","y":[2921],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"main_category=Games<br>category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"Games","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Games","offsetgroup":"Games","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Tabletop Games"],"xaxis":"x","y":[4079],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"main_category=Journalism<br>category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"Journalism","marker":{"col ...

# %% [markdown]
# **Gráfico variable "country"**
# > Distribución de los proyectos por país

# %%
proyectos_pais= pd.pivot_table(ks, 
               index=["country"], 
               values="ID", 
               aggfunc="count")
proyectos_pais=proyectos_pais.reset_index()
proyectos_pais
# Out:
#    country     ID
# 0       AT    140
# 1       AU   1793
# 2       BE    149
# 3       CA   3589
# 4       CH    192
# 5       DE   1042
# 6       DK    272
# 7       ES    503
# 8       FR    756
# 9       GB   8534
# 10      HK    160
# 11      IE    192
# 12      IT    630
# 13      JP     11
# 14      LU     14
# 15      MX    394
# 16      NL    650
# 17      NO    175
# 18      NZ    379
# 19      SE    434
# 20      SG    137
# 21      US  75721

# %%
fig_proyectos_pais = px.bar(proyectos_pais,
            x = 'country',
            y = 'ID',
            title='Cantidad de proyectos por país',
            text_auto = True)
fig_proyectos_pais = fig_proyectos_pais.update_xaxes(categoryorder = 'total descending')
fig_proyectos_pais
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c7489671-1850-4cba-8b7a-960e2748e03b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7489671-1850-4cba-8b7a-960e2748e03b")) {                    Plotly.newPlot(                        "c7489671-1850-4cba-8b7a-960e2748e03b",                        [{"alignmentgroup":"True","hovertemplate":"country=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["AT","AU","BE","CA","CH","DE","DK","ES","FR","GB","HK","IE","IT","JP","LU","MX","NL","NO","NZ","SE","SG","US"],"xaxis":"x","y":[140,1793,149,3589,192,1042,272,503,756,8534,160,192,630,11,14,394,650,175,379,434,137,75721],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","si ...

# %% [markdown]
# **Gráfico variable "currency"**
#
#
# > Cantidad de proyectos por moneda

# %%
proyectos_moneda= pd.pivot_table(ks, 
               index=["currency"], 
               values="ID", 
               aggfunc="count")
proyectos_moneda=proyectos_moneda.reset_index()
proyectos_moneda
# Out:
#    currency     ID
# 0       AUD   1793
# 1       CAD   3589
# 2       CHF    192
# 3       DKK    272
# 4       EUR   4076
# 5       GBP   8534
# 6       HKD    160
# 7       JPY     11
# 8       MXN    394
# 9       NOK    175
# 10      NZD    379
# 11      SEK    434
# 12      SGD    137
# 13      USD  75721

# %%
fig_proyectos_moneda= px.bar(proyectos_moneda,
       x = 'currency',
       y = 'ID',
       title='Cantidad de proyectos por moneda',
       text_auto = True)
fig_proyectos_moneda = fig_proyectos_moneda.update_xaxes(categoryorder = 'total descending')
fig_proyectos_moneda
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="0e9b5194-de8f-4133-b218-7b7c4abe2f1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e9b5194-de8f-4133-b218-7b7c4abe2f1e")) {                    Plotly.newPlot(                        "0e9b5194-de8f-4133-b218-7b7c4abe2f1e",                        [{"alignmentgroup":"True","hovertemplate":"currency=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["AUD","CAD","CHF","DKK","EUR","GBP","HKD","JPY","MXN","NOK","NZD","SEK","SGD","USD"],"xaxis":"x","y":[1793,3589,192,272,4076,8534,160,11,394,175,379,434,137,75721],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"t ...

# %% [markdown]
# **Gráfico variable "state"**
#
#
# > 1. Cantidad de proyectos según su estado.
#
# > 2. Cantidad de proyectos en cada estado para cada categoría global.

# %%
#1. Cantidad de proyectos según su estado
proyectos_estado= pd.pivot_table(ks, 
               index=["state"], 
               values="ID", 
               aggfunc="count")
proyectos_estado=proyectos_estado.reset_index()
proyectos_estado
# Out:
#         state     ID
# 0    canceled   7876
# 1      failed  47875
# 2  successful  40116

# %%
fig_proyectos_estado = px.bar(proyectos_estado,
            x = 'state',
            y = 'ID',
            title='Cantidad de proyectos según su estado',
            text_auto = True)
fig_proyectos_estado = fig_proyectos_estado.update_xaxes(categoryorder = 'total descending')
fig_proyectos_estado
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="74cb40db-0b30-47e4-991a-6df6775e24c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74cb40db-0b30-47e4-991a-6df6775e24c1")) {                    Plotly.newPlot(                        "74cb40db-0b30-47e4-991a-6df6775e24c1",                        [{"alignmentgroup":"True","hovertemplate":"state=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["canceled","failed","successful"],"xaxis":"x","y":[7876,47875,40116],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"s ...

# %%
#2 cantidad de proyectos en cada estado para cada categoría global
proyectos_estado_category= pd.pivot_table(ks, 
               index=["main_category","state"], 
               values="ID", 
               aggfunc="count")
proyectos_estado_category=proyectos_estado_category.reset_index()
proyectos_estado_category
# Out:
#    main_category       state    ID
# 0            Art    canceled   382
# 1            Art      failed  3312
# 2            Art  successful  3428
# 3         Comics    canceled   191
# 4         Comics      failed  1118
# 5         Comics  successful  1765
# 6         Crafts    canceled   147
# 7         Crafts      failed  1286
# 8         Crafts  successful   654
# 9          Dance    canceled    30
# 10         Dance      failed   302
# 11         Dance  successful   664
# 12        Design    canceled  1090
# 13        Design      failed  4071
# 14        Design  successful  3133
# 15       Fashion    canceled   523
# 16       Fashion      failed  3289
# 17       Fashion  successful  1705
# 18  Film & Video    canceled  1108
# 19  Film & Video      failed  7671
# 20  Film & Video  successful  7151
# 21          Food    canceled   394
# 22          Food      failed  3807
# 23          Food  successful  1818
# 24         Games    canceled  1522
# 25         Games      failed  4409
# 26         Games  successful  3764
# 27    Journalism    canceled    77
# 28    Journalism      failed   671
# 29    Journalism  successful   308
# 30         Music    canceled   545
# 31         Music      failed  5067
# 32         Music  successful  7240
# 33   Photography    canceled   136
# 34   Photography      failed  1472
# 35   Photography  successful  1011
# 36    Publishing    canceled   588
# 37    Publishing      failed  5460
# 38    Publishing  successful  3655
# 39    Technology    canceled  1030
# 40    Technology      failed  5013
# 41    Technology  successful  1896
# 42       Theater    canceled   113
# 43       Theater      failed   927
# 44       Theater  successful  1924

# %%
fig_proyectos_estado_category = px.bar(proyectos_estado_category,
            x = 'main_category',
            y = 'ID',
            color = 'state',
            title='Cantidad de proyectos en cada estado para cada categoría global',
            text_auto = True)
fig_proyectos_estado_category
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="65610feb-1bad-4c2a-ad6b-bd872dd99db3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65610feb-1bad-4c2a-ad6b-bd872dd99db3")) {                    Plotly.newPlot(                        "65610feb-1bad-4c2a-ad6b-bd872dd99db3",                        [{"alignmentgroup":"True","hovertemplate":"state=canceled<br>main_category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"canceled","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"canceled","offsetgroup":"canceled","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Art","Comics","Crafts","Dance","Design","Fashion","Film & Video","Food","Games","Journalism","Music","Photography","Publishing","Technology","Theater"],"xaxis":"x","y":[382,191,147,30,1090,523,1108,394,1522,77,545,136,588,1030,113],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"state=failed<br>main_category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"failed","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"failed","offsetgroup":"failed","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Art","Comics","Crafts","Dance","Design","Fashion","Film & Video","Food","Games","Journalism","Music","Photography","Publishing","Technology","Theater"],"xaxis":"x","y":[3312,1118,1286,302,4071,3289,7671,3807,4409,671,5067,1472,5460,5013,927],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"state=successful<br>main_category=%{x}<br>ID=%{y}<extra></extra>","legendgroup":"successful","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"successful","offsetgroup":"successful","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Art","Comics","Crafts","Dance","Design","Fashion","Film & Video","Food","Games","Journalism","Music","Photography","Publishing","Technology","Theater"],"xaxis":"x","y":[3428,1765,654,664,3133,1705,7151,1818,3764,308,7240,1011,3655,1896,1924],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{ ...

# %%
fig_proyectos_estado_category_2 = px.histogram(proyectos_estado_category,
            x = 'main_category',
            y = 'ID',
            color = 'state',
            barnorm='fraction',
            title='Cantidad de proyectos en cada estado para cada categoría global',
            text_auto = True)
fig_proyectos_estado_category_2
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="1f70a55c-24d8-4d3a-b121-3a5b596fdfe2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f70a55c-24d8-4d3a-b121-3a5b596fdfe2")) {                    Plotly.newPlot(                        "1f70a55c-24d8-4d3a-b121-3a5b596fdfe2",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"state=canceled<br>main_category=%{x}<br>sum of ID (normalized as fraction)=%{y}<extra></extra>","legendgroup":"canceled","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"canceled","offsetgroup":"canceled","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Art","Comics","Crafts","Dance","Design","Fashion","Film & Video","Food","Games","Journalism","Music","Photography","Publishing","Technology","Theater"],"xaxis":"x","y":[382,191,147,30,1090,523,1108,394,1522,77,545,136,588,1030,113],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"state=failed<br>main_category=%{x}<br>sum of ID (normalized as fraction)=%{y}<extra></extra>","legendgroup":"failed","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"failed","offsetgroup":"failed","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Art","Comics","Crafts","Dance","Design","Fashion","Film & Video","Food","Games","Journalism","Music","Photography","Publishing","Technology","Theater"],"xaxis":"x","y":[3312,1118,1286,302,4071,3289,7671,3807,4409,671,5067,1472,5460,5013,927],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"state=successful<br>main_category=%{x}<br>sum of ID (normalized as fraction)=%{y}<extra></extra>","legendgroup":"successful","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"successful","offsetgroup":"successful","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Art","Comics","Crafts","Dance","Design","Fashion","Film & Video","Food","Games","Journalism","Music","Photography","Publishing","Technology","Theater"],"xaxis":"x","y":[3428,1765,654,664,3133,1705,7151,1818,3764,308,7240,1011,3655,1896,1924],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778," ...

# %% [markdown]
# **Gráfico variable "backers"**
#
#
# > 1. Cantidad total de participantes en cada categoría global o principal.
#
#
# > 2. Mayor cantidad de participantes en un proyecto de cada categoría global o principal

# %%
suma_participantes= ks['backers'].sum()
suma_participantes
# Out:
# 11537465

# %%
#1 Cantidad total de participantes en cada categoría global o principal.
participantes = pd.pivot_table(ks, 
               index=["main_category"],
               values="backers", 
               aggfunc="sum")

participantes = participantes.reset_index()
participantes

#se puede ver la cantidad de participantes que hay en cada categoría especifica.
# Out:
#    main_category  backers
# 0            Art   328606
# 1         Comics   402623
# 2         Crafts    82480
# 3          Dance    45402
# 4         Design  2013237
# 5        Fashion   436374
# 6   Film & Video  1298521
# 7           Food   365814
# 8          Games  3131197
# 9     Journalism    48235
# 10         Music   807622
# 11   Photography   118288
# 12    Publishing   671489
# 13    Technology  1643122
# 14       Theater   144455

# %%
graf_cant_participantes = px.histogram(participantes,
            x = "main_category",
            y = "backers",
            title='Cantidad total de participantes en cada categoría global o principal',
            text_auto = True)
graf_cant_participantes = graf_cant_participantes.update_xaxes(categoryorder = 'total descending')
graf_cant_participantes
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="07ccf4ae-cc9a-4a92-9de6-13afce88d845" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07ccf4ae-cc9a-4a92-9de6-13afce88d845")) {                    Plotly.newPlot(                        "07ccf4ae-cc9a-4a92-9de6-13afce88d845",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"main_category=%{x}<br>sum of backers=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"texttemplate":"%{value}","x":["Art","Comics","Crafts","Dance","Design","Fashion","Film & Video","Food","Games","Journalism","Music","Photography","Publishing","Technology","Theater"],"xaxis":"x","y":[328606,402623,82480,45402,2013237,436374,1298521,365814,3131197,48235,807622,118288,671489,1643122,144455],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":" ...

# %%
#2 Mayor cantidad de participantes en un proyecto de cada categoría global o principal
max_participantes = ks.groupby('main_category')['backers'].idxmax()

# %%
participantes_max = ks.loc[max_participantes, ['main_category', 'backers']]
participantes_max
# Out:
#       main_category  backers
# 5973            Art     3290
# 84768        Comics     6466
# 66548        Crafts    12705
# 30350         Dance      863
# 41875        Design    44949
# 30657       Fashion    13642
# 67718  Film & Video    91585
# 81044          Food     9293
# 66996         Games    73206
# 32440    Journalism     1951
# 12168         Music    10768
# 51010   Photography     1570
# 57876    Publishing    21808
# 70316    Technology   105857
# 44366       Theater     1577

# %%
fig_max_participantes = px.bar(participantes_max,
            x = 'main_category',
            y = 'backers',
            title='Mayor cantidad de participantes en un proyecto de cada categoría global o principal',
            text_auto = True)
fig_max_participantes=fig_max_participantes.update_xaxes(categoryorder = 'total descending')
fig_max_participantes
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="facf57cb-b061-47e3-bbf0-865b068c8212" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("facf57cb-b061-47e3-bbf0-865b068c8212")) {                    Plotly.newPlot(                        "facf57cb-b061-47e3-bbf0-865b068c8212",                        [{"alignmentgroup":"True","hovertemplate":"main_category=%{x}<br>backers=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Art","Comics","Crafts","Dance","Design","Fashion","Film & Video","Food","Games","Journalism","Music","Photography","Publishing","Technology","Theater"],"xaxis":"x","y":[3290,6466,12705,863,44949,13642,91585,9293,73206,1951,10768,1570,21808,105857,1577],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","wid ...

# %% [markdown]
# **Gráfico variable "usd_pledged_real"**

# %%
montoganado_proyecto = pd.pivot_table(ks, 
               index="main_category",
               values="usd_pledged_real", 
               aggfunc="sum")
 
montoganado_proyecto = montoganado_proyecto.reset_index()
montoganado_proyecto
# Out:
#    main_category  usd_pledged_real
# 0            Art      2.701127e+07
# 1         Comics      1.916994e+07
# 2         Crafts      4.721591e+06
# 3          Dance      3.823008e+06
# 4         Design      2.078638e+08
# 5        Fashion      4.161255e+07
# 6   Film & Video      1.207574e+08
# 7           Food      3.540098e+07
# 8          Games      2.111995e+08
# 9     Journalism      3.315122e+06
# 10         Music      5.890089e+07
# 11   Photography      1.107044e+07
# 12    Publishing      4.070494e+07
# 13    Technology      1.982055e+08
# 14       Theater      1.207538e+07

# %%
graf_montoporproyecto = px.histogram(montoganado_proyecto,
            x = "main_category",
            y = "usd_pledged_real",
            text_auto = True)
graf_montoporproyecto = graf_montoporproyecto.update_xaxes(categoryorder = 'total descending')
graf_montoporproyecto
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ec3cd43b-12aa-4bc7-93a3-7298cf0113ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec3cd43b-12aa-4bc7-93a3-7298cf0113ea")) {                    Plotly.newPlot(                        "ec3cd43b-12aa-4bc7-93a3-7298cf0113ea",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"main_category=%{x}<br>sum of usd_pledged_real=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"texttemplate":"%{value}","x":["Art","Comics","Crafts","Dance","Design","Fashion","Film & Video","Food","Games","Journalism","Music","Photography","Publishing","Technology","Theater"],"xaxis":"x","y":[27011266.53,19169944.96,4721590.69,3823008.33,207863802.43,41612547.63,120757425.93,35400981.75,211199479.94,3315121.61,58900891.74,11070443.72,40704939.2,198205496.51,12075378.07],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlin ...

# %% [markdown]
# **Gráfico variable "usd_goal_real"**

# %%
ks["monto_meta"] = ks['usd_pledged_real'] - ks['usd_goal_real']

def clasificar_diferencia(monto_meta):
    if monto_meta > 0:
        return 'Sí'
    else:
        return 'No'

ks['clasificacion'] = ks['monto_meta'].apply(clasificar_diferencia)

ks
# Out:
#                ID                                               name  \
# 0      1730140959    Beaconz - The App to Map Everything! (Canceled)
# 1      1689190720          Character Trait Endorsing Between Friends
# 2      1719536806  Project Portal - People helping people, for fr...
# 3       903714362    On the Record - Inside the World of Stenography
# 4       166739996        C Grayson Ponchos, "Our Fashion is the ART"
# ...           ...                                                ...
# 95862   313363232                Contour Electric Blue Playing Cards
# 95863  1863949134  Clash of the Monsters - The Horror Genre Fight...
# 95864  1728934253                   Dropship Custom LEGO Element Kit
# 95865   236314934  Show Dogs: Small business in the Great Lakes r...
# 95866   570806201                                        Open Verses
#
#              category main_category currency       state  backers country  \
# 0                Apps    Technology      GBP    canceled        5      GB
# 1                Apps    Technology      USD      failed        3      US
# 2                 Web    Technology      USD      failed        2      US
# 3         Documentary  Film & Video      USD  successful        9      US
# 4             Fashion       Fashion      USD      failed        8      US
# ...               ...           ...      ...         ...      ...     ...
# 95862   Playing Cards         Games      USD  successful      106      US
# 95863     Video Games         Games      USD  successful       40      US
# 95864  Product Design        Design      USD  successful       67      US
# 95865     Food Trucks          Food      USD      failed        1      US
# 95866         Hip-Hop         Music      USD      failed        1      US
#
#        usd_pledged_real  usd_goal_real  monto_meta clasificacion
# 0               8127.18       92424.29   -84297.11            No
# 1                 35.00       10000.00    -9965.00            No
# 2                 51.00        1500.00    -1449.00            No
# 3              15151.10       14900.00      251.10            Sí
# 4                211.00       30000.00   -29789.00            No
# ...                 ...            ...         ...           ...
# 95862           2975.00        2500.00      475.00            Sí
# 95863           1722.00        1000.00      722.00            Sí
# 95864           5747.00        3200.00     2547.00            Sí
# 95865              3.00        9990.00    -9987.00            No
# 95866              2.00        1500.00    -1498.00            No
#
# [95867 rows x 12 columns]

# %%
meta_real_proyecto= pd.pivot_table(ks, 
               index=["main_category","clasificacion"], 
               values="ID", 
               aggfunc="count")
meta_real_proyecto=meta_real_proyecto.reset_index()
meta_real_proyecto
# Out:
#    main_category clasificacion    ID
# 0            Art            No  3818
# 1            Art            Sí  3304
# 2         Comics            No  1322
# 3         Comics            Sí  1752
# 4         Crafts            No  1450
# 5         Crafts            Sí   637
# 6          Dance            No   363
# 7          Dance            Sí   633
# 8         Design            No  5143
# 9         Design            Sí  3151
# 10       Fashion            No  3838
# 11       Fashion            Sí  1679
# 12  Film & Video            No  9075
# 13  Film & Video            Sí  6855
# 14          Food            No  4244
# 15          Food            Sí  1775
# 16         Games            No  5910
# 17         Games            Sí  3785
# 18    Journalism            No   761
# 19    Journalism            Sí   295
# 20         Music            No  5881
# 21         Music            Sí  6971
# 22   Photography            No  1635
# 23   Photography            Sí   984
# 24    Publishing            No  6159
# 25    Publishing            Sí  3544
# 26    Technology            No  6033
# 27    Technology            Sí  1906
# 28       Theater            No  1150
# 29       Theater            Sí  1814

# %%
graf_clas_montorealproyecto = px.histogram(meta_real_proyecto,
            x = 'main_category',
            y = 'ID',
            color = 'clasificacion',
            text_auto = True)
graf_clas_montorealproyecto
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e15ae495-a319-4e14-8569-3e7986db5510" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e15ae495-a319-4e14-8569-3e7986db5510")) {                    Plotly.newPlot(                        "e15ae495-a319-4e14-8569-3e7986db5510",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"clasificacion=No<br>main_category=%{x}<br>sum of ID=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Art","Comics","Crafts","Dance","Design","Fashion","Film & Video","Food","Games","Journalism","Music","Photography","Publishing","Technology","Theater"],"xaxis":"x","y":[3818,1322,1450,363,5143,3838,9075,4244,5910,761,5881,1635,6159,6033,1150],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"clasificacion=S\u00ed<br>main_category=%{x}<br>sum of ID=%{y}<extra></extra>","legendgroup":"S\u00ed","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"S\u00ed","offsetgroup":"S\u00ed","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Art","Comics","Crafts","Dance","Design","Fashion","Film & Video","Food","Games","Journalism","Music","Photography","Publishing","Technology","Theater"],"xaxis":"x","y":[3304,1752,637,633,3151,1679,6855,1775,3785,295,6971,984,3544,1906,1814],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.33333333 ...

# %%
#Cuantitativas = histograma, box plot. si hay sesgo, etc
#Cualitativas = de barras, conteo.

# %% [markdown]
# ##2. Definir un criterio

# %% [markdown]
# Basado en los datos, para determinar qué hace que un proyecto sea bueno. ¿Cómo cambiaría este criterio si Kickstarter no utilizara el modelo all-or-nothing?

# %%
#Criterio basico = si es exitoso es bueno
#Otro criterio = exitoso, proyectos que junten mucha plata
#Otro criterio = juntan mucha plata pero se pusieron una meta mas alta, entonces con respecto a su meta
#Otro criterio = numero de personas que aportan al proyecto (# de buckers)
# cuanta plata pone un bucket en promedio
#Hay algunas personas que no son realistas con la meta de plata, y algunos se llevan la plata.

# %%
#Modelo all or nothing = la plata que juntes te la doy, ahí cambia el criterio.

# %% [markdown]
# ##3. Determine el tipo de proyecto
# Para la campaña de crowdfunding que su grupo recomienda, usando los criterios definidos anteriormente.
